# %%
import pandas as pd
from tqdm import tqdm
from datetime import datetime
import time as time

import selenium
from selenium import webdriver

from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys

# %%
path_to_driver = "../chromedriver_win32/chromedriver.exe"

# %%
#calling the webdriver for viz
browser = webdriver.Chrome(executable_path=path_to_driver)

# %%
url = 'https://www.geekswhodrink.com/schedule/TX'

# %%
#finding the URL
browser.get(url)

# %%
time.sleep(8)

# %%
#setting up a cat
data ={}
dow = []
venue = []
city = []
time = []
urls = []
date = []

# %%
day = [day.text for day in browser.find_elements_by_tag_name("h3")[2:]]

# %%
#finds the urls between each h3 header
for stuff in tqdm(range(len(days))):
    
    for i in browser.find_elements_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div['+str(stuff)+']'):
        for links in i.find_elements_by_tag_name("a"):
            urls.append(links.get_attribute("href"))
            venue.append(links.text)
            dow.append(days[stuff])
        for c in i.find_elements_by_tag_name("i"):
            city.append(c.text)
        for t in i.find_elements_by_tag_name("time"):
            if (t.text[0]).isnumeric() == True:
                time.append(t.text)
            else: 
                date.append(t.text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:14<00:00,  2.34s/it]

# %% [raw]
# *********************** PREVIOUS CODE *********************************************************
# #loops through each line and finds locaiton, day and time.
# for item in tqdm(range(len(browser.find_elements_by_tag_name("h3")))):
#     for t in range(75):
#         try:
#             venue.append(browser.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div/div/div/div[1]/div/div["+str(item)+"]/div/div["+str(t)+"]/a/span").text)
#             dow.append(browser.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div[1]/div/div['+str(item)+']/h3').text)
#         except:
#             pass

# %%
len(city),len(venue),len(dow),len(time),len(urls)
# Out:
# (172, 172, 172, 172, 172)

# %%
df = pd.DataFrame(data=[city,venue,dow,time,urls]).T

# %%
df.columns = ['city','venue','dow','time','urls']
browser.close()

# %%
df.head()
# Out:
#           city                              venue     dow     time  \
# 0     (Austin)   Black Star Co-Op Pub and Brewery  Monday  8:00 PM
# 1     (Dallas)               Four Corners Brewing  Monday  5:00 PM
# 2    (El Paso)  Glass Half Full (El Paso, Sunday)  Monday  5:00 PM
# 3      (Wylie)                Good Neighbor Brews  Monday  5:00 PM
# 4  (Grapevine)   Grapevine Craft Brewery (Sunday)  Monday  5:00 PM
#
#                                                 urls
# 0  https://www.geekswhodrink.com/venue/19199768/t...
# 1  https://www.geekswhodrink.com/venue/771599801/...
# 2  https://www.geekswhodrink.com/venue/613308526/...
# 3  https://www.geekswhodrink.com/venue/576262892/...
# 4  https://www.geekswhodrink.com/venue/654369627/...

# %%
austin  = df[df['city'] == '(Austin)']

# %%
df.to_csv('./data/'+str(datetime.today())[:10]+'_GWD.csv')

# %%
austin = austin.reset_index(drop=True)

# %%
austin.to_csv('./data/'+str(datetime.today())[:10]+'_GWD_Austin.csv')

# %%
austin
# Out:
#         city                                           venue        dow  \
# 0   (Austin)                Black Star Co-Op Pub and Brewery     Monday
# 1   (Austin)                                    The Cavalier     Monday
# 2   (Austin)                                    The Highball     Monday
# 3   (Austin)  400 Rabbits at Alamo Drafthouse Slaughter Lane    Tuesday
# 4   (Austin)                 Austin Eastciders Collaboratory    Tuesday
# 5   (Austin)                      Glass Half Full (Lakeline)    Tuesday
# 6   (Austin)          Gourdough's Public House (South Lamar)    Tuesday
# 7   (Austin)                            Growler USA (Austin)    Tuesday
# 8   (Austin)                                        Javelina    Tuesday
# 9   (Austin)        Barrel O' Fun (Alamo Drafthouse Mueller)  Wednesday
# 10  (Austin)                     Big Daddy's Burgers and Bar  Wednesday
# 11  (Austin)                                   Celis Brewery  Wednesday
# 12  (Austin)                                     Craft Pride  Wednesday
# 13  (Austin)                                      Gibson Bar  Wednesday
# 14  (Austin)                               Lustre Pearl East  Wednesday
# 15  (Austin)                                Moontower Saloon  Wednesday
# 16  (Austin)                                     Nickel City  Wednesday
# 17  (Austin)                     Oasis Texas Brewing Company  Wednesday
# 18  (Austin)                    Opal Divine's (Austin Grill)  Wednesday
# 19  (Austin)                        Pinthouse Pizza (Burnet)  Wednesday
# 20  (Austin)                                     Red's Porch  Wednesday
# 21  (Austin)                          The Brass Tap (Domain)  Wednesday
# 22  (Austin)                  The Butterfly Bar @ The VORTEX  Wednesday
# 23  (Austin)                              Adelbert's Brewery   Thursday
# 24  (Austin)                               Billy's on Burnet   Thursday
# 25  (Austin)                                       Gourmands   Thursday
# 26  (Austin)                                   Mister Tramps   Thursday
# 27  (Austin)                   Pinthouse Pizza (South Lamar)   Thursday
# 28  (Austin)                                Sour Duck Market   Thursday
# 29  (Austin)                                The Spider House   Thursday
# 30  (Austin)                          Third Base (NorthWest)   Thursday
# 31  (Austin)                                 Trifecta on 3rd   Thursday
# 32  (Austin)               WhichCraft Tap Room & Bottle Shop   Thursday
# 33  (Austin)                              Austin Daily Press   Saturday
# 34  (Austin)                              Flying Man Brewery   Saturday
# 35  (Austin)                        Independence Brewing Co.   Saturday
# 36  (Austin)                                   Indian Roller   Saturday
# 37  (Austin)                                      Knomad Bar   Saturday
# 38  (Austin)                                   The Iron Bear   Saturday
# 39  (Austin)                 Third Base (South Park Meadows)   Saturday
# 40  (Austin)                            Trudy's (North Star)   Saturday
#
#        time                                               urls
# 0   8:00 PM  https://www.geekswhodrink.com/venue/19199768/t...
# 1   7:00 PM  https://www.geekswhodrink.com/venue/859909510/...
