# %%
import pandas as pd
from tqdm import tqdm
from datetime import datetime

import selenium
from selenium import webdriver

from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys

# %%
path_to_driver = "../chromedriver_win32/chromedriver.exe"

# %%
#calling the webdriver for viz
browser = webdriver.Chrome(executable_path=path_to_driver)

# %%
url = 'https://www.geekswhodrink.com/schedule/TX'

# %%
#finding the URL
browser.get(url)

# %%
#setting up a cat
data ={}
dow = []
location = []
city = []
time = []
urls = []
date = []

# %%
#finds the urls between each h3 header
for i in browser.find_elements_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div[1]'):
    for links in i.find_elements_by_tag_name("a"):
        urls.append(links.get_attribute("href"))
    for c in i.find_elements_by_tag_name("i"):
        city.append(c.text)
    for t in i.find_elements_by_tag_name("time"):
        if (t.text[0]).isnumeric() == True:
            time.append(t.text)
        else: 
            date.append(t.text)

# %%
for item in browser.find_elements_by_tag_name("h3"):
    for links in item.find_elements_by_tag_name("a"):
        len(links.get_attribute('href'))

# %%
#loops through each line and finds locaiton, day and time.
for item in tqdm(range(len(browser.find_elements_by_tag_name("h3")))):
    for t in range(75):
        try:
            location.append(browser.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div/div/div/div[1]/div/div["+str(item)+"]/div/div["+str(t)+"]/a/span").text)
            dow.append(browser.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div[1]/div/div['+str(item)+']/h3').text)
        except:
            pass
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:19<00:00,  2.49s/it]

# %%
len(city),len(location),len(dow),len(time),len(urls)
# Out:
# (176, 176, 176, 176, 176)

# %%
df = pd.DataFrame(data=[city,location,dow,time,urls]).T

# %%
df.columns = ['city','location','dow','time','urls']
browser.close()

# %%
df.head()
# Out:
#           city                           location     dow     time  \
# 0     (Austin)   Black Star Co-Op Pub and Brewery  Sunday  8:00 PM
# 1     (Dallas)               Four Corners Brewing  Sunday  5:00 PM
# 2    (El Paso)  Glass Half Full (El Paso, Sunday)  Sunday  5:00 PM
# 3      (Wylie)                Good Neighbor Brews  Sunday  5:00 PM
# 4  (Grapevine)   Grapevine Craft Brewery (Sunday)  Sunday  5:00 PM
#
#                                                 urls
# 0  https://www.geekswhodrink.com/venue/19199768/t...
# 1  https://www.geekswhodrink.com/venue/771599801/...
# 2  https://www.geekswhodrink.com/venue/613308526/...
# 3  https://www.geekswhodrink.com/venue/576262892/...
# 4  https://www.geekswhodrink.com/venue/654369627/...

# %%
df[df['city'] == '(Austin)']
# Out:
#          city                                        location        dow  \
# 0    (Austin)                Black Star Co-Op Pub and Brewery     Sunday
# 5    (Austin)                                    The Cavalier     Sunday
# 6    (Austin)                                    The Highball     Sunday
# 9    (Austin)  400 Rabbits at Alamo Drafthouse Slaughter Lane     Monday
# 11   (Austin)                 Austin Eastciders Collaboratory     Monday
# 16   (Austin)                      Glass Half Full (Lakeline)     Monday
# 18   (Austin)          Gourdough's Public House (South Lamar)     Monday
# 19   (Austin)                            Growler USA (Austin)     Monday
# 23   (Austin)                                        Javelina     Monday
# 38   (Austin)        Barrel O' Fun (Alamo Drafthouse Mueller)    Tuesday
# 39   (Austin)                     Big Daddy's Burgers and Bar    Tuesday
# 42   (Austin)                                   Celis Brewery    Tuesday
# 47   (Austin)                                     Craft Pride    Tuesday
# 50   (Austin)                                      Gibson Bar    Tuesday
# 62   (Austin)                               Lustre Pearl East    Tuesday
# 63   (Austin)                                Moontower Saloon    Tuesday
# 64   (Austin)                                     Nickel City    Tuesday
# 65   (Austin)                     Oasis Texas Brewing Company    Tuesday
# 67   (Austin)                    Opal Divine's (Austin Grill)    Tuesday
# 68   (Austin)                        Pinthouse Pizza (Burnet)    Tuesday
# 71   (Austin)                                     Red's Porch    Tuesday
# 78   (Austin)                          The Brass Tap (Domain)    Tuesday
# 79   (Austin)                  The Butterfly Bar @ The VORTEX    Tuesday
# 91   (Austin)                              Adelbert's Brewery  Wednesday
# 94   (Austin)                               Billy's on Burnet  Wednesday
# 103  (Austin)                                       Gourmands  Wednesday
# 109  (Austin)                                   Mister Tramps  Wednesday
# 116  (Austin)                   Pinthouse Pizza (South Lamar)  Wednesday
# 119  (Austin)                                Sour Duck Market  Wednesday
# 126  (Austin)                                The Spider House  Wednesday
# 127  (Austin)                          Third Base (NorthWest)  Wednesday
# 131  (Austin)                                 Trifecta on 3rd  Wednesday
# 134  (Austin)               WhichCraft Tap Room & Bottle Shop  Wednesday
# 139  (Austin)                              Austin Daily Press   Thursday
# 144  (Austin)                              Flying Man Brewery   Thursday
# 149  (Austin)                        Independence Brewing Co.   Thursday
# 150  (Austin)                                   Indian Roller   Thursday
# 151  (Austin)                                      Knomad Bar   Thursday
# 163  (Austin)                                   The Iron Bear   Thursday
# 165  (Austin)                 Third Base (South Park Meadows)   Thursday
# 168  (Austin)                            Trudy's (North Star)   Thursday
# 171  (Austin)                 Coffee Shark Espresso and Pints   Saturday
# 174  (Austin)                          Opal Divine's (Marina)   Saturday
#
#          time                                               urls
# 0     8:00 PM  https://www.geekswhodrink.com/venue/19199768/t...
# 5     7:00 PM  https://www.geekswhodrink.com/venue/859909510/...
# 6     7:00 PM  https://www.geekswhodrink.com/venue/16729898/t...
# 9     8:00 PM  https://www.geekswhodrink.com/venue/37034165/t...
# 11    8:00 PM  https://www.geekswhodrink.com/venue/736622458/...
